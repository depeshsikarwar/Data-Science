# %% [markdown]
# <a href="https://colab.research.google.com/github/depeshsikarwar/Data-Science/blob/main/lec03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multi(a,b):
    return a*b
print(multi(3,4))
# Out:
# 12

# %%
def add(a,b):
    return a+b

print(add(3,4));
# Out:
# 7

# %%
# lambda function
x=lambda a,b : 2*(a+b)
print(x(2,3))
# Out:
# 10

# %%
# STRING
st=""
print(len(st))
st="LancHenBa Myanlambam Singh"
print(st.upper())
print(st.lower())
print(st.title())
print(st.find("Ba"))
print(st.capitalize())
# count do the length of a particular character
print(st.count("a"))
st1="Depesh"
st2="Sikarwar"
# Strip remove spaces
print(st1.strip())
print(" ".join([st1,st2]))
print(st1.replace("e","a"))
# Out:
# 0
# LANCHENBA MYANLAMBAM SINGH
# lanchenba myanlambam singh
# Lanchenba Myanlambam Singh
# 7
# Lanchenba myanlambam singh
# 5
# Depesh
# Depesh Sikarwar
# Dapash

# %%
a="today Hello My Groww"
b="  weather  "
c="is Good  "
print(a.lstrip()+" "+b.strip()+" "+c.rstrip())
print(a.find("a"))
print(sorted(a))
print(a.split())
# Out:
# today Hello My Groww weather is Good
# 3
# [' ', ' ', ' ', 'G', 'H', 'M', 'a', 'd', 'e', 'l', 'l', 'o', 'o', 'o', 'r', 't', 'w', 'w', 'y', 'y']
# ['today', 'Hello', 'My', 'Groww']

# %%
st={2,2,2,3,2,12,34,4}
print(st)
  # set sort by default and remove duplicate
# Out:
# {2, 3, 4, 34, 12}

# %%
# Dictionary
dct={
    "name":["Ramesh","lanchenba","jagjeet"],
    "age":[18,21,21],
    "class":["Btech","BCA","MCA"],
    "Roll_no":[1,2,3]
}
print(dct)
print(dct["name"][0])
print(dct["age"])
dct['id']=12
print(dct)
del dct["name"]
print(dct)
# Out:
# {'name': ['Ramesh', 'lanchenba', 'jagjeet'], 'age': [18, 21, 21], 'class': ['Btech', 'BCA', 'MCA'], 'Roll_no': [1, 2, 3]}
# Ramesh
# [18, 21, 21]
# {'name': ['Ramesh', 'lanchenba', 'jagjeet'], 'age': [18, 21, 21], 'class': ['Btech', 'BCA', 'MCA'], 'Roll_no': [1, 2, 3], 'id': 12}
# {'age': [18, 21, 21], 'class': ['Btech', 'BCA', 'MCA'], 'Roll_no': [1, 2, 3], 'id': 12}
